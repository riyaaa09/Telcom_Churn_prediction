# %%
# !pip install pandas numpy scikit-learn matplotlib seaborn jupyter pyarrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (2.3.5)
# Requirement already satisfied: scikit-learn in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (1.7.0)
# Requirement already satisfied: matplotlib in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (3.10.3)
# Requirement already satisfied: seaborn in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (0.13.2)
# Requirement already satisfied: jupyter in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (1.1.1)
# Requirement already satisfied: pyarrow in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (20.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: notebook in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter) (7.2.2)
# Requirement already satisfied: jupyter-console in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter) (7.16.4)
# Requirement already satisfied: ipykernel in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: ipywidgets in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter) (8.1.5)
# Requirement already satisfied: jupyterlab in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter) (4.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (1.8.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (8.29.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (6.1.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: decorator in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: colorama in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (308)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipywidgets->jupyter) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from ipywidgets->jupyter) (3.0.13)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyterlab->jupyter) (2.0.4)
# Collecting httpx>=0.25.0 (from jupyterlab->jupyter)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyterlab->jupyter) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyterlab->jupyter) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyterlab->jupyter) (75.3.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.6.2.post1)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.14)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: certifi in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2024.8.30)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab->jupyter)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.20.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.8.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from nbconvert->jupyter) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: webencodings in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.2.3)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.6)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20241003)
# Requirement already satisfied: executing>=1.2.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: h11, httpcore, httpx
#
#   Attempting uninstall: h11
#
#     Found existing installation: h11 0.9.0
#
#     Uninstalling h11-0.9.0:
#
#       Successfully uninstalled h11-0.9.0
#
#    ---------------------------------------- 0/3 [h11]
#    ---------------------------------------- 0/3 [h11]
#    ---------------------------------------- 0/3 [h11]
#    ---------------------------------------- 0/3 [h11]
#   Attempting uninstall: httpcore
#    ---------------------------------------- 0/3 [h11]
#     Found existing installation: httpcore 0.9.1
#    ---------------------------------------- 0/3 [h11]
#    ------------- -------------------------- 1/3 [httpcore]
#     Uninstalling httpcore-0.9.1:
#    ------------- -------------------------- 1/3 [httpcore]
#       Successfully uninstalled httpcore-0.9.1
#    ------------- -------------------------- 1/3 [httpcore]
#    ------------- -------------------------- 1/3 [httpcore]
#    ------------- -------------------------- 1/3 [httpcore]
#    ------------- -------------------------- 1/3 [httpcore]
#    ------------- -------------------------- 1/3 [httpcore]
#    ------------- -------------------------- 1/3 [httpcore]
#    ------------- -------------------------- 1/3 [httpcore]
#    ------------- -------------------------- 1/3 [httpcore]
#    ------------- -------------------------- 1/3 [httpcore]
#    ------------- -------------------------- 1/3 [httpcore]
#    ------------- -------------------------- 1/3 [httpcore]
#   Attempting uninstall: httpx
#    ------------- -------------------------- 1/3 [httpcore]
#     Found existing installation: httpx 0.13.3
#    ------------- -------------------------- 1/3 [httpcore]
#     Uninstalling httpx-0.13.3:
#    ------------- -------------------------- 1/3 [httpcore]
#       Successfully uninstalled httpx-0.13.3
#    ------------- -------------------------- 1/3 [httpcore]
#    -------------------------- ------------- 2/3 [httpx]
#    -------------------------- ------------- 2/3 [httpx]
#    -------------------------- ------------- 2/3 [httpx]
#    -------------------------- ------------- 2/3 [httpx]
#    -------------------------- ------------- 2/3 [httpx]
#    -------------------------- ------------- 2/3 [httpx]
#    -------------------------- ------------- 2/3 [httpx]
#    -------------------------- ------------- 2/3 [httpx]
#    -------------------------- ------------- 2/3 [httpx]
#    -------------------------- ------------- 2/3 [httpx]
#    ---------------------------------------- 3/3 [httpx]
#
# Successfully installed h11-0.16.0 httpcore-1.0.9 httpx-0.28.1
#   WARNING: The script httpx.exe is installed in 'C:\Users\my lenovo\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# googletrans 4.0.0rc1 requires httpx==0.13.3, but you have httpx 0.28.1 which is incompatible.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install sqlalchemy pymysql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.46-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting pymysql
#   Using cached pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.3.1-cp313-cp313-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\my lenovo\appdata\roaming\python\python313\site-packages (from sqlalchemy) (4.14.0)
# Downloading sqlalchemy-2.0.46-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------  2.1/2.1 MB 18.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 13.8 MB/s  0:00:00
# Using cached pymysql-1.1.2-py3-none-any.whl (45 kB)
# Downloading greenlet-3.3.1-cp313-cp313-win_amd64.whl (227 kB)
# Installing collected packages: pymysql, greenlet, sqlalchemy
#
#    ---------------------------------------- 0/3 [pymysql]
#    ---------------------------------------- 0/3 [pymysql]
#    ---------------------------------------- 0/3 [pymysql]
#    ---------------------------------------- 0/3 [pymysql]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    ---------------------------------------- 3/3 [sqlalchemy]
#
# Successfully installed greenlet-3.3.1 pymysql-1.1.2 sqlalchemy-2.0.46
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 3.1 Imports & data read

import pandas as pd
import numpy as np
from pathlib import Path

RAW = Path("../capstone")

cust = pd.read_csv(RAW/"customers.csv")
usage = pd.read_csv(RAW/"usage_data.csv")
comp = pd.read_csv(RAW/"complaints.csv", parse_dates=["created_at"])
bill = pd.read_csv(RAW/"billing.csv")

print(cust.shape, usage.shape, comp.shape, bill.shape)
cust.head()
# Out:
# (10, 4) (10, 4) (10, 4) (10, 5)
#    customer_id         name plan_type   region
# 0         1001   Asha Mehta   Prepaid    Delhi
# 1         1002   Ravi Kumar  Postpaid   Mumbai
# 2         1003    Sneha Rao   Prepaid  Chennai
# 3         1004  Manoj Singh  Postpaid    Delhi
# 4         1005   Divya Jain   Prepaid  Kolkata

# %%
# 3.2 Basic validation

for df,name in [(cust,"customers"),(usage,"usage"),(comp,"complaints"),(bill,"billing")]:
    print(name, "nulls:\n", df.isna().sum(), "\n")
# Out:
# customers nulls:
#  customer_id    0
# name           0
# plan_type      0
# region         0
# dtype: int64
#
# usage nulls:
#  customer_id     0
# data_used_gb    0
# calls_made      0
# revenue_inr     0
# dtype: int64
#
# complaints nulls:
#  customer_id    0
# category       0
# created_at     0
# status         0
# dtype: int64
#
# billing nulls:
#  customer_id        0
# tenure             0
# contract_type      0
# monthly_charges    0
# churn              0
# dtype: int64

# %%
# 3.3 Light cleaning (fixable—not dropping)

# Trim/case normalisation
cust["region"]    = cust["region"].str.title().str.strip()
cust["plan_type"] = cust["plan_type"].str.title().str.strip()

# Fill numeric gaps sensibly
for col in ["data_used_gb","calls_made","revenue_inr"]:
    usage[col] = usage[col].fillna(usage[col].median())

bill["monthly_charges"] = bill["monthly_charges"].fillna(bill["monthly_charges"].median())
bill["tenure"] = bill["tenure"].fillna(bill["tenure"].median())

# Fill complaints fields
comp["status"]   = comp["status"].fillna("Resolved")
comp["category"] = comp["category"].fillna("General")

# Convert churn to 0/1 flag
bill["churn_flag"] = (bill["churn"].str.lower() == "yes").astype(int)

# %%
# 3.4 Aggregate complaints to customer level

complaint_agg = (comp
   .groupby("customer_id")
   .agg(
       complaints_total = ("category","count"),
       complaints_open  = ("status", lambda s: (s.str.lower()=="open").sum())
   )
   .reset_index()
)
complaint_agg.head()
# Out:
#    customer_id  complaints_total  complaints_open
# 0         1002                 2                2
# 1         1003                 1                1
# 2         1004                 1                1
# 3         1005                 1                0
# 4         1006                 1                0

# %%
# 3.5 Join all tables

df = (cust
      .merge(usage, on="customer_id", how="left")
      .merge(complaint_agg, on="customer_id", how="left")
      .merge(bill, on="customer_id", how="left"))

# Fill new NaNs created by left joins
df[["complaints_total","complaints_open"]] = df[["complaints_total","complaints_open"]].fillna(0).astype(int)

# Final sanity checks
print(df.isna().sum())
df.head()
# Out:
# customer_id         0
# name                0
# plan_type           0
# region              0
# data_used_gb        0
# calls_made          0
# revenue_inr         0
# complaints_total    0
# complaints_open     0
# tenure              0
# contract_type       0
# monthly_charges     0
# churn               0
# churn_flag          0
# dtype: int64
#    customer_id         name plan_type   region  data_used_gb  calls_made  \
# 0         1001   Asha Mehta   Prepaid    Delhi           5.2          25
# 1         1002   Ravi Kumar  Postpaid   Mumbai          12.5          40
# 2         1003    Sneha Rao   Prepaid  Chennai           7.8          32
# 3         1004  Manoj Singh  Postpaid    Delhi          15.6          55
# 4         1005   Divya Jain   Prepaid  Kolkata           3.4          18
#
#    revenue_inr  complaints_total  complaints_open  tenure   contract_type  \
# 0          180                 0                0      12  Month-to-Month
# 1          280                 2                2      24        One Year
# 2          210                 1                1       8  Month-to-Month
# 3          320                 1                1      30        One Year
# 4          120                 1                0       6  Month-to-Month
#
#    monthly_charges churn  churn_flag
# 0              180   Yes           1
# 1              280    No           0
# 2              210   Yes           1
# 3              320    No           0
# 4              120   Yes           1

# %%
# 3.6 Save master dataset

OUT = Path("../outputs")
OUT.mkdir(exist_ok=True)
df.to_csv(OUT/"telecom_master.csv", index=False)
print("Saved:", OUT/"telecom_master.csv")
# Out:
# Saved: ..\outputs\telecom_master.csv

# %%
# 4) Create Churn Model

import pandas as pd, seaborn as sns, matplotlib.pyplot as plt
df = pd.read_csv("../outputs/telecom_master.csv")

# Churn rate
print(df["churn_flag"].mean().round(3))   # e.g., 0.23 -> 23%

# Churn by plan/region
sns.barplot(x="plan_type", y="churn_flag", data=df); plt.title("Churn by Plan"); plt.show()
sns.barplot(x="region", y="churn_flag", data=df);    plt.title("Churn by Region"); plt.xticks(rotation=30); plt.show()

# Revenue vs churn
sns.boxplot(x="churn_flag", y="monthly_charges", data=df); plt.title("Charges vs Churn"); plt.show()

# Correlations (numeric only)
num = df.select_dtypes("number")
sns.heatmap(num.corr(), cmap="vlag", center=0); plt.title("Numeric Corr"); plt.show()

# %%
# 5.1 Setup features

import pandas as pd, numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report
import joblib, json, matplotlib.pyplot as plt, seaborn as sns

df = pd.read_csv("../outputs/telecom_master.csv")

# Choose simple, strong baseline features
features = [
    "tenure","monthly_charges","data_used_gb","calls_made","revenue_inr",
    "complaints_total","complaints_open",
    "contract_type","plan_type","region"
]
target = "churn_flag"

X = df[features].copy()
y = df[target].copy()

cat_cols = ["contract_type","plan_type","region"]
num_cols = [c for c in X.columns if c not in cat_cols]

# %%
# 5.2 Preprocessor + models

pre = ColumnTransformer([
    ("num", StandardScaler(), num_cols),
    ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols)
])

logit = Pipeline([
  ("prep", pre),
  ("clf", LogisticRegression(max_iter=1000, class_weight="balanced"))
])

tree = Pipeline([
  ("prep", pre),
  ("clf", DecisionTreeClassifier(max_depth=6, class_weight="balanced", random_state=42))
])

# %%
# 5.3 Train/test split & training

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

logit.fit(X_train, y_train)
tree.fit(X_train, y_train)

# %%
5.4 Evaluate
# 
def evaluate(name, model):
    pred = model.predict(X_test)
    proba = getattr(model, "predict_proba", lambda X: np.c_[1-pred, pred])(X_test)[:,1]
    acc = accuracy_score(y_test, pred)
    p, r, f1, _ = precision_recall_fscore_support(y_test, pred, average="binary")
    print(f"{name} -> Acc:{acc:.3f}  Prec:{p:.3f}  Rec:{r:.3f}  F1:{f1:.3f}")

    cm = confusion_matrix(y_test, pred)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title(f"{name} Confusion Matrix"); plt.xlabel("Pred"); plt.ylabel("True"); plt.show()
    return acc, p, r, f1

metrics = {}
for nm, mdl in [("Logistic", logit), ("DecisionTree", tree)]:
    acc,p,r,f1 = evaluate(nm, mdl)
    metrics[nm] = dict(accuracy=acc, precision=p, recall=r, f1=f1)

with open("../outputs/model_metrics.json","w") as f:
    json.dump(metrics, f, indent=2)
metrics

Goal: Hit a reasonable baseline (e.g., accuracy 0.70–0.85, recall decent for catching churn).
If recall is low, try deeper tree (max_depth=8), or add/engineer features (e.g., ARPU = revenue_inr / max(1, tenure)).

# %%
# 5.5 Pick the winner & persist

best = logit if metrics["Logistic"]["f1"] >= metrics["DecisionTree"]["f1"] else tree
joblib.dump(best, "../outputs/model.pkl")
print("Saved best model.")

# %%
# 5.6 Export predictions for BI

best = joblib.load("../outputs/model.pkl")
df_pred = df.copy()
df_pred["churn_prob"] = best.predict_proba(X)[:,1]
df_pred["churn_pred"] = (df_pred["churn_prob"] >= 0.5).astype(int)
df_pred.to_csv("../outputs/predictions.csv", index=False)
print("Saved predictions.csv")
